# %% [markdown]
# # Week 2: Predicting time series
#
# Welcome! In the previous assignment you got some exposure to working with time series data, but you didn't use machine learning techniques for your forecasts. This week you will be using a deep neural network to create forecasts to see how this technique compares with the ones you already tried out. Once again all of the data is going to be generated.
#
# Let's get started!

# %% [markdown]
# _**NOTE:** To prevent errors from the autograder, you are not allowed to edit or delete some of the cells in this notebook . Please only put your solutions in between the `### START CODE HERE` and `### END CODE HERE` code comments, and also refrain from adding any new cells. **Once you have passed this assignment** and want to experiment with any of the locked cells, you may follow the instructions at the bottom of this notebook._

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from dataclasses import dataclass

# %% [markdown]
# ## Generating the data
#
#
# The next cell includes a bunch of helper functions to generate and plot the time series:

# %%
def plot_series(time, series, format="-", start=0, end=None):
    plt.plot(time[start:end], series[start:end], format)
    plt.xlabel("Time")
    plt.ylabel("Value")
    plt.grid(False)

def trend(time, slope=0):
    return slope * time

def seasonal_pattern(season_time):
    """An arbitrary pattern"""
    return np.where(season_time < 0.1,
                    np.cos(season_time * 6 * np.pi), 
                    2 / np.exp(9 * season_time))

def seasonality(time, period, amplitude=1, phase=0):
    """Repeats the same pattern at each period"""
    season_time = ((time + phase) % period) / period
    return amplitude * seasonal_pattern(season_time)

def noise(time, noise_level=1, seed=None):
    rnd = np.random.RandomState(seed)
    return rnd.randn(len(time)) * noise_level

# %% [markdown]
# You will be generating time series data that greatly resembles the one from last week but with some differences.
#
# **Notice that this time all the generation is done within a function and global variables are saved within a dataclass. This is done to avoid using global scope as it was done in during the previous week.**
#
# If you haven't used dataclasses before, they are just Python classes that provide a convenient syntax for storing data. You can read more about them in the [docs](https://docs.python.org/3/library/dataclasses.html).

# %%
def generate_time_series():
    # The time dimension or the x-coordinate of the time series
    time = np.arange(4 * 365 + 1, dtype="float32")

    # Initial series is just a straight line with a y-intercept
    y_intercept = 10
    slope = 0.005
    series = trend(time, slope) + y_intercept

    # Adding seasonality
    amplitude = 50
    series += seasonality(time, period=365, amplitude=amplitude)

    # Adding some noise
    noise_level = 3
    series += noise(time, noise_level, seed=51)
    
    return time, series


# Save all "global" variables within the G class (G stands for global)
@dataclass
class G:
    TIME, SERIES = generate_time_series()
    SPLIT_TIME = 1100
    WINDOW_SIZE = 20
    BATCH_SIZE = 32
    SHUFFLE_BUFFER_SIZE = 1000
    

# Plot the generated series
plt.figure(figsize=(10, 6))
plot_series(G.TIME, G.SERIES)
plt.show()

# %% [markdown]
# ## Splitting the data
#
# Since you already coded the `train_val_split` function during last week's assignment, this time it is provided for you:

# %%
def train_val_split(time, series, time_step=G.SPLIT_TIME):

    time_train = time[:time_step]
    series_train = series[:time_step]
    time_valid = time[time_step:]
    series_valid = series[time_step:]

    return time_train, series_train, time_valid, series_valid


# Split the dataset
time_train, series_train, time_valid, series_valid = train_val_split(G.TIME, G.SERIES)

# %% [markdown]
# ## Processing the data
#
# As you saw on the lectures you can feed the data for training by creating a dataset with the appropiate processing steps such as `windowing`, `flattening`, `batching` and `shuffling`. To do so complete the `windowed_dataset` function below.
#
# Notice that this function receives a `series`, `window_size`, `batch_size` and `shuffle_buffer` and the last three of these default to the "global" values defined earlier.
#
# Be sure to check out the [docs](https://www.tensorflow.org/api_docs/python/tf/data/Dataset) about `TF Datasets` if you need any help.

# %%
def windowed_dataset(series, window_size=G.WINDOW_SIZE, batch_size=G.BATCH_SIZE, shuffle_buffer=G.SHUFFLE_BUFFER_SIZE):
    
    ### START CODE HERE
    
    # Create dataset from the series
    dataset = tf.data.Dataset.from_tensor_slices(series)
    
    # Slice the dataset into the appropriate windows
    dataset = dataset.window(window_size+1, shift=1, drop_remainder=True)
    
    # Flatten the dataset
    dataset = dataset.flat_map(lambda window: window.batch(window_size+1))
    
    # Shuffle it
    dataset = dataset.shuffle(shuffle_buffer)
    
    # Split it into the features and labels
    dataset = dataset.map(lambda window: (window[:-1], window[-1]))
    
    # Batch it
    dataset = dataset.batch(batch_size).prefetch(1)
    
    ### END CODE HERE
    
    return dataset

# %% [markdown]
# To test your function you will be using a `window_size` of 1 which means that you will use each value to predict the next one. This for 5 elements since a `batch_size` of 5 is used and no shuffle since `shuffle_buffer` is set to 1.
#
# Given this, the batch of features should be identical to the first 5 elements of the `series_train` and the batch of labels should be equal to elements 2 through 6 of the `series_train`.

# %%
# Test your function with windows size of 1 and no shuffling
test_dataset = windowed_dataset(series_train, window_size=1, batch_size=5, shuffle_buffer=1)

# Get the first batch of the test dataset
batch_of_features, batch_of_labels = next((iter(test_dataset)))

print(f"batch_of_features has type: {type(batch_of_features)}\n")
print(f"batch_of_labels has type: {type(batch_of_labels)}\n")
print(f"batch_of_features has shape: {batch_of_features.shape}\n")
print(f"batch_of_labels has shape: {batch_of_labels.shape}\n")
print(f"batch_of_features is equal to first five elements in the series: {np.allclose(batch_of_features.numpy().flatten(), series_train[:5])}\n")
print(f"batch_of_labels is equal to first five labels: {np.allclose(batch_of_labels.numpy(), series_train[1:6])}")
# Out:
# batch_of_features has type: <class 'tensorflow.python.framework.ops.EagerTensor'>
#
# batch_of_labels has type: <class 'tensorflow.python.framework.ops.EagerTensor'>
#
# batch_of_features has shape: (5, 1)
#
# batch_of_labels has shape: (5,)
#
# batch_of_features is equal to first five elements in the series: True
#
# batch_of_labels is equal to first five labels: True

# %% [markdown]
# **Expected Output:**
#
# ```
# batch_of_features has type: <class 'tensorflow.python.framework.ops.EagerTensor'>
#
# batch_of_labels has type: <class 'tensorflow.python.framework.ops.EagerTensor'>
#
# batch_of_features has shape: (5, 1)
#
# batch_of_labels has shape: (5,)
#
# batch_of_features is equal to first five elements in the series: True
#
# batch_of_labels is equal to first five labels: True
# ```

# %% [markdown]
# ## Defining the model architecture
#
# Now that you have a function that will process the data before it is fed into your neural network for training, it is time to define you layer architecture.
#
# Complete the `create_model` function below. Notice that this function receives the `window_size` since this will be an important parameter for the first layer of your network.
#
# Hint:
# - You will only need `Dense` layers.
# - Do not include `Lambda` layers. These are not required and are incompatible with the `HDF5` format which will be used to save your model for grading.
# - The training should be really quick so if you notice that each epoch is taking more than a few seconds, consider trying a different architecture.

# %%
def create_model(window_size=G.WINDOW_SIZE):

    ### START CODE HERE

    model = tf.keras.models.Sequential([ 
        #tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32, input_shape=[window_size]))
        tf.keras.layers.Dense(64, input_shape=[window_size]),
        tf.keras.layers.Dense(32, activation='relu'),
        tf.keras.layers.Dense(16, activation='relu'),
        tf.keras.layers.Dense(8, activation='relu'),
        tf.keras.layers.Dense(1, activation='relu')
    ]) 

    model.compile(loss='mse',
                  optimizer=tf.keras.optimizers.SGD(learning_rate=4e-6,momentum=0.9))
    
    ### END CODE HERE

    return model

# %%
# Apply the processing to the whole training series
dataset = windowed_dataset(series_train)

# Save an instance of the model
model = create_model()

# Train it
model.fit(dataset, epochs=500)
# Out:
# Epoch 1/500
# 34/34 [==============================] - 0s 3ms/step - loss: 220.0083
# Epoch 2/500
# 34/34 [==============================] - 0s 1ms/step - loss: 74.8540
# Epoch 3/500
# 34/34 [==============================] - 0s 1ms/step - loss: 52.6852
# Epoch 4/500
# 34/34 [==============================] - 0s 1ms/step - loss: 43.2960
# Epoch 5/500
# 34/34 [==============================] - 0s 1ms/step - loss: 38.9962
# Epoch 6/500
# 34/34 [==============================] - 0s 1ms/step - loss: 36.4803
# Epoch 7/500
# 34/34 [==============================] - 0s 2ms/step - loss: 34.0485
# Epoch 8/500
# 34/34 [==============================] - 0s 1ms/step - loss: 32.6297
# Epoch 9/500
# 34/34 [==============================] - 0s 1ms/step - loss: 31.5585
# Epoch 10/500
# 34/34 [==============================] - 0s 1ms/step - loss: 31.1555
# Epoch 11/500
# 34/34 [==============================] - 0s 1ms/step - loss: 30.4671
# Epoch 12/500
# 34/34 [==============================] - 0s 881us/step - loss: 30.2968
# Epoch 13/500
# 34/34 [==============================] - 0s 1ms/step - loss: 29.3601
# Epoch 14/500
# 34/34 [==============================] - 0s 1ms/step - loss: 29.2216
# Epoch 15/500
# 34/34 [==============================] - 0s 2ms/step - loss: 28.4815
# Epoch 16/500
# 34/34 [==============================] - 0s 1ms/step - loss: 28.5534
# Epoch 17/500
# 34/34 [==============================] - 0s 2ms/step - loss: 28.2391
# Epoch 18/500
# 34/34 [==============================] - 0s 1ms/step - loss: 27.9554
# Epoch 19/500
# 34/34 [==============================] - 0s 2ms/step - loss: 27.4848
# Epoch 20/500
# 34/34 [==============================] - 0s 1ms/step - loss: 27.5956
# Epoch 21/500
# 34/34 [==============================] - 0s 2ms/step - loss: 27.1782
# Epoch 22/500
# 34/34 [==============================] - 0s 1ms/step - loss: 27.1494
# Epoch 23/500
# 34/34 [==============================] - 0s 1ms/step - loss: 26.6418
# Epoch 24/500
# 34/34 [==============================] - 0s 1ms/step - loss: 26.6153
# Epoch 25/500
# 34/34 [==============================] - 0s 1ms/step - loss: 27.4711
# Epoch 26/500
# 34/34 [==============================] - 0s 1ms/step - loss: 26.7096
# Epoch 27/500
# 34/34 [==============================] - 0s 1ms/step - loss: 26.0659
# Epoch 28/500
# 34/34 [==============================] - 0s 2ms/step - loss: 26.3327
# Epoch 29/500
# 34/34 [==============================] - 0s 1ms/step - loss: 26.2157
# Epoch 30/500
# 34/34 [==============================] - 0s 1ms/step - loss: 26.1723
# Epoch 31/500
# 34/34 [==============================] - 0s 1ms/step - loss: 25.8723
# Epoch 32/500
# 34/34 [==============================] - 0s 2ms/step - loss: 25.6484
# Epoch 33/500
# 34/34 [==============================] - 0s 1ms/step - loss: 25.5634
# Epoch 34/500
# 34/34 [==============================] - 0s 1ms/step - loss: 26.8002
# Epoch 35/500
# 34/34 [==============================] - 0s 1ms/step - loss: 25.2913
# Epoch 36/500
# 34/34 [==============================] - 0s 1ms/step - loss: 25.1407
# Epoch 37/500
# 34/34 [==============================] - 0s 1ms/step - loss: 25.5226
# Epoch 38/500
# 34/34 [==============================] - 0s 1ms/step - loss: 24.9730
# Epoch 39/500
# 34/34 [==============================] - 0s 1ms/step - loss: 25.1412
# Epoch 40/500
# 34/34 [==============================] - 0s 1ms/step - loss: 25.1373
# Epoch 41/500
# 34/34 [==============================] - 0s 1ms/step - loss: 25.4361
# Epoch 42/500
# 34/34 [==============================] - 0s 1ms/step - loss: 25.0604
# Epoch 43/500
# 34/34 [==============================] - 0s 1ms/step - loss: 24.9039
# Epoch 44/500
# 34/34 [==============================] - 0s 1ms/step - loss: 24.9249
# Epoch 45/500
# 34/34 [==============================] - 0s 1ms/step - loss: 24.5137
# Epoch 46/500
# 34/34 [==============================] - 0s 1ms/step - loss: 24.7553
# Epoch 47/500
# 34/34 [==============================] - 0s 1ms/step - loss: 24.5360
# Epoch 48/500
# 34/34 [==============================] - 0s 1ms/step - loss: 24.7516
# Epoch 49/500
# 34/34 [==============================] - 0s 1ms/step - loss: 24.3885
# Epoch 50/500
# 34/34 [==============================] - 0s 1ms/step - loss: 24.3067
# Epoch 51/500
# 34/34 [==============================] - 0s 2ms/step - loss: 24.4566
# Epoch 52/500
# 34/34 [==============================] - 0s 1ms/step - loss: 24.5634
# Epoch 53/500
# 34/34 [==============================] - 0s 1ms/step - loss: 25.1530
# Epoch 54/500
# 34/34 [==============================] - 0s 1ms/step - loss: 24.4796
# Epoch 55/500
# 34/34 [==============================] - 0s 1ms/step - loss: 24.1868
# Epoch 56/500
# 34/34 [==============================] - 0s 963us/step - loss: 24.1772
# Epoch 57/500
# 34/34 [==============================] - 0s 1ms/step - loss: 24.5917
# Epoch 58/500
# 34/34 [==============================] - 0s 1ms/step - loss: 24.1160
# Epoch 59/500
# 34/34 [==============================] - 0s 1ms/step - loss: 24.1635
# Epoch 60/500
# 34/34 [==============================] - 0s 1ms/step - loss: 23.6541
# Epoch 61/500
# 34/34 [==============================] - 0s 994us/step - loss: 23.8965
# Epoch 62/500
# 34/34 [==============================] - 0s 1ms/step - loss: 23.6624
# Epoch 63/500
# 34/34 [==============================] - 0s 1ms/step - loss: 24.2723
# Epoch 64/500
# 34/34 [==============================] - 0s 1ms/step - loss: 25.0781
# Epoch 65/500
# 34/34 [==============================] - 0s 1ms/step - loss: 24.5440
# Epoch 66/500
# 34/34 [==============================] - 0s 1ms/step - loss: 23.7109
# Epoch 67/500
# 34/34 [==============================] - 0s 1ms/step - loss: 23.7896
# Epoch 68/500
# 34/34 [==============================] - 0s 978us/step - loss: 23.9644
# Epoch 69/500
# 34/34 [==============================] - 0s 1ms/step - loss: 23.9046
# Epoch 70/500
# 34/34 [==============================] - 0s 1ms/step - loss: 23.3880
# Epoch 71/500
# 34/34 [==============================] - 0s 1ms/step - loss: 23.3341
# Epoch 72/500
# 34/34 [==============================] - 0s 1ms/step - loss: 23.3578
# Epoch 73/500
# 34/34 [==============================] - 0s 1ms/step - loss: 23.3249
# Epoch 74/500
# 34/34 [==============================] - 0s 1ms/step - loss: 23.2747
# Epoch 75/500
# 34/34 [==============================] - 0s 1ms/step - loss: 23.4773
# Epoch 76/500
# 34/34 [==============================] - 0s 1ms/step - loss: 23.4385
# Epoch 77/500
# 34/34 [==============================] - 0s 1ms/step - loss: 23.2437
# Epoch 78/500
# 34/34 [==============================] - 0s 976us/step - loss: 22.8538
# Epoch 79/500
# 34/34 [==============================] - 0s 1ms/step - loss: 23.1475
# Epoch 80/500
# 34/34 [==============================] - 0s 1ms/step - loss: 23.2337
# Epoch 81/500
# 34/34 [==============================] - 0s 1ms/step - loss: 23.3542
# Epoch 82/500
# 34/34 [==============================] - 0s 1ms/step - loss: 23.1978
# Epoch 83/500
# 34/34 [==============================] - 0s 1ms/step - loss: 22.8682
# Epoch 84/500
# 34/34 [==============================] - 0s 1ms/step - loss: 22.7370
# Epoch 85/500
# 34/34 [==============================] - 0s 925us/step - loss: 23.4272
# Epoch 86/500
# 34/34 [==============================] - 0s 1ms/step - loss: 23.1913
# Epoch 87/500
# 34/34 [==============================] - 0s 1ms/step - loss: 22.7202
# Epoch 88/500
# 34/34 [==============================] - 0s 1ms/step - loss: 22.5745
# Epoch 89/500
# 34/34 [==============================] - 0s 1ms/step - loss: 22.6422
# Epoch 90/500
# 34/34 [==============================] - 0s 1ms/step - loss: 22.9780
# Epoch 91/500
# 34/34 [==============================] - 0s 1ms/step - loss: 22.7426
# Epoch 92/500
# 34/34 [==============================] - 0s 1ms/step - loss: 22.7822
# Epoch 93/500
# 34/34 [==============================] - 0s 1ms/step - loss: 22.6415
# Epoch 94/500
# 34/34 [==============================] - 0s 1ms/step - loss: 22.3278
# Epoch 95/500
# 34/34 [==============================] - 0s 1ms/step - loss: 22.5599
# Epoch 96/500
# 34/34 [==============================] - 0s 1ms/step - loss: 22.6909
# Epoch 97/500
# 34/34 [==============================] - 0s 1ms/step - loss: 22.2971
# Epoch 98/500
# 34/34 [==============================] - 0s 959us/step - loss: 22.2017
# Epoch 99/500
# 34/34 [==============================] - 0s 1ms/step - loss: 22.9731
# Epoch 100/500
# 34/34 [==============================] - 0s 1ms/step - loss: 22.6272
# Epoch 101/500
# 34/34 [==============================] - 0s 1ms/step - loss: 22.1376
# Epoch 102/500
# 34/34 [==============================] - 0s 1ms/step - loss: 22.7421
# Epoch 103/500
# 34/34 [==============================] - 0s 1ms/step - loss: 22.5504
# Epoch 104/500
# 34/34 [==============================] - 0s 993us/step - loss: 22.0846
# Epoch 105/500
# 34/34 [==============================] - 0s 1ms/step - loss: 21.6808
# Epoch 106/500
# 34/34 [==============================] - 0s 1ms/step - loss: 21.5976
# Epoch 107/500
# 34/34 [==============================] - 0s 1ms/step - loss: 21.8639
# Epoch 108/500
# 34/34 [==============================] - 0s 1ms/step - loss: 22.1759
# Epoch 109/500
# 34/34 [==============================] - 0s 1ms/step - loss: 22.2524
# Epoch 110/500
# 34/34 [==============================] - 0s 1ms/step - loss: 21.8963
# Epoch 111/500
# 34/34 [==============================] - 0s 1ms/step - loss: 21.9383
# Epoch 112/500
# 34/34 [==============================] - 0s 1ms/step - loss: 21.7281
# Epoch 113/500
# 34/34 [==============================] - 0s 1ms/step - loss: 22.0784
# Epoch 114/500
# 34/34 [==============================] - 0s 1ms/step - loss: 21.9885
# Epoch 115/500
# 34/34 [==============================] - 0s 1ms/step - loss: 21.3694
# Epoch 116/500
# 34/34 [==============================] - 0s 1ms/step - loss: 21.6878
# Epoch 117/500
# 34/34 [==============================] - 0s 1ms/step - loss: 21.7107
# Epoch 118/500
# 34/34 [==============================] - 0s 1ms/step - loss: 21.6073
# Epoch 119/500
# 34/34 [==============================] - 0s 1ms/step - loss: 21.6443
# Epoch 120/500
# 34/34 [==============================] - 0s 1ms/step - loss: 21.3228
# Epoch 121/500
# 34/34 [==============================] - 0s 1ms/step - loss: 22.0042
# Epoch 122/500
# 34/34 [==============================] - 0s 1ms/step - loss: 21.3455
# Epoch 123/500
# 34/34 [==============================] - 0s 1ms/step - loss: 21.2811
# Epoch 124/500
# 34/34 [==============================] - 0s 2ms/step - loss: 21.0662
# Epoch 125/500
# 34/34 [==============================] - 0s 1ms/step - loss: 21.0943
# Epoch 126/500
# 34/34 [==============================] - 0s 1ms/step - loss: 21.3272
# Epoch 127/500
# 34/34 [==============================] - 0s 1ms/step - loss: 21.2201
# Epoch 128/500
# 34/34 [==============================] - 0s 1ms/step - loss: 21.2486
# Epoch 129/500
# 34/34 [==============================] - 0s 1ms/step - loss: 21.3638
# Epoch 130/500
# 34/34 [==============================] - 0s 1ms/step - loss: 21.0758
# Epoch 131/500
# 34/34 [==============================] - 0s 1ms/step - loss: 22.0650
# Epoch 132/500
# 34/34 [==============================] - 0s 1ms/step - loss: 21.0179
# Epoch 133/500
# 34/34 [==============================] - 0s 1ms/step - loss: 20.9600
# Epoch 134/500
# 34/34 [==============================] - 0s 1ms/step - loss: 20.5999
# Epoch 135/500
# 34/34 [==============================] - 0s 1ms/step - loss: 20.3831
# Epoch 136/500
# 34/34 [==============================] - 0s 1ms/step - loss: 20.4280
# Epoch 137/500
# 34/34 [==============================] - 0s 1ms/step - loss: 20.6220
# Epoch 138/500
# 34/34 [==============================] - 0s 1ms/step - loss: 20.4756
# Epoch 139/500
# 34/34 [==============================] - 0s 1ms/step - loss: 21.0793
# Epoch 140/500
# 34/34 [==============================] - 0s 1ms/step - loss: 20.6963
# Epoch 141/500
# 34/34 [==============================] - 0s 1ms/step - loss: 20.6138
# Epoch 142/500
# 34/34 [==============================] - 0s 1ms/step - loss: 20.3912
# Epoch 143/500
# 34/34 [==============================] - 0s 1ms/step - loss: 20.5701
# Epoch 144/500
# 34/34 [==============================] - 0s 1ms/step - loss: 20.5814
# Epoch 145/500
# 34/34 [==============================] - 0s 1ms/step - loss: 21.0922
# Epoch 146/500
# 34/34 [==============================] - 0s 1ms/step - loss: 21.0597
# Epoch 147/500
# 34/34 [==============================] - 0s 1ms/step - loss: 20.1412
# Epoch 148/500
# 34/34 [==============================] - 0s 2ms/step - loss: 20.1070
# Epoch 149/500
# 34/34 [==============================] - 0s 1ms/step - loss: 20.6054
# Epoch 150/500
# 34/34 [==============================] - 0s 1ms/step - loss: 20.0297
# Epoch 151/500
# 34/34 [==============================] - 0s 1ms/step - loss: 20.0376
# Epoch 152/500
# 34/34 [==============================] - 0s 1ms/step - loss: 19.8897
# Epoch 153/500
# 34/34 [==============================] - 0s 1ms/step - loss: 20.1684
# Epoch 154/500
# 34/34 [==============================] - 0s 1ms/step - loss: 20.2474
# Epoch 155/500
# 34/34 [==============================] - 0s 1ms/step - loss: 20.3749
# Epoch 156/500
# 34/34 [==============================] - 0s 2ms/step - loss: 20.3389
# Epoch 157/500
# 34/34 [==============================] - 0s 1ms/step - loss: 19.9645
# Epoch 158/500
# 34/34 [==============================] - 0s 2ms/step - loss: 20.4442
# Epoch 159/500
# 34/34 [==============================] - 0s 1ms/step - loss: 20.0428
# Epoch 160/500
# 34/34 [==============================] - 0s 1ms/step - loss: 19.9631
# Epoch 161/500
# 34/34 [==============================] - 0s 1ms/step - loss: 19.6765
# Epoch 162/500
# 34/34 [==============================] - 0s 1ms/step - loss: 19.6652
# Epoch 163/500
# 34/34 [==============================] - 0s 2ms/step - loss: 20.2460
# Epoch 164/500
# 34/34 [==============================] - 0s 1ms/step - loss: 19.5359
# Epoch 165/500
# 34/34 [==============================] - 0s 1ms/step - loss: 20.0057
# Epoch 166/500
# 34/34 [==============================] - 0s 1ms/step - loss: 19.6968
# Epoch 167/500
# 34/34 [==============================] - 0s 1ms/step - loss: 19.6944
# Epoch 168/500
# 34/34 [==============================] - 0s 1ms/step - loss: 19.2844
# Epoch 169/500
# 34/34 [==============================] - 0s 1ms/step - loss: 19.8141
# Epoch 170/500
# 34/34 [==============================] - 0s 1ms/step - loss: 20.3769
# Epoch 171/500
# 34/34 [==============================] - 0s 1ms/step - loss: 19.6783
# Epoch 172/500
# 34/34 [==============================] - 0s 2ms/step - loss: 19.5998
# Epoch 173/500
# 34/34 [==============================] - 0s 1ms/step - loss: 19.9983
# Epoch 174/500
# 34/34 [==============================] - 0s 1ms/step - loss: 19.5916
# Epoch 175/500
# 34/34 [==============================] - 0s 1ms/step - loss: 19.4776
# Epoch 176/500
# 34/34 [==============================] - 0s 1ms/step - loss: 20.1029
# Epoch 177/500
# 34/34 [==============================] - 0s 1ms/step - loss: 19.7300
# Epoch 178/500
# 34/34 [==============================] - 0s 1ms/step - loss: 20.2125
# Epoch 179/500
# 34/34 [==============================] - 0s 973us/step - loss: 19.6981
# Epoch 180/500
# 34/34 [==============================] - 0s 1ms/step - loss: 19.2356
# Epoch 181/500
# 34/34 [==============================] - 0s 1ms/step - loss: 19.4266
# Epoch 182/500
# 34/34 [==============================] - 0s 1ms/step - loss: 20.2772
# Epoch 183/500
# 34/34 [==============================] - 0s 1ms/step - loss: 19.7624
# Epoch 184/500
# 34/34 [==============================] - 0s 1ms/step - loss: 19.1488
# Epoch 185/500
# 34/34 [==============================] - 0s 1ms/step - loss: 19.2043
# Epoch 186/500
# 34/34 [==============================] - 0s 1ms/step - loss: 19.2176
# Epoch 187/500
# 34/34 [==============================] - 0s 1ms/step - loss: 19.3424
# Epoch 188/500
# 34/34 [==============================] - 0s 1ms/step - loss: 19.3016
# Epoch 189/500
# 34/34 [==============================] - 0s 1ms/step - loss: 18.7586
# Epoch 190/500
# 34/34 [==============================] - 0s 1ms/step - loss: 19.0801
# Epoch 191/500
# 34/34 [==============================] - 0s 961us/step - loss: 19.1338
# Epoch 192/500
# 34/34 [==============================] - 0s 967us/step - loss: 19.3904
# Epoch 193/500
# 34/34 [==============================] - 0s 1ms/step - loss: 18.8171
# Epoch 194/500
# 34/34 [==============================] - 0s 969us/step - loss: 18.6895
# Epoch 195/500
# 34/34 [==============================] - 0s 1ms/step - loss: 18.9791
# Epoch 196/500
# 34/34 [==============================] - 0s 1ms/step - loss: 18.5870
# Epoch 197/500
# 34/34 [==============================] - 0s 1ms/step - loss: 19.6774
# Epoch 198/500
# 34/34 [==============================] - 0s 1ms/step - loss: 18.9511
# Epoch 199/500
# 34/34 [==============================] - 0s 1ms/step - loss: 18.8895
# Epoch 200/500
# 34/34 [==============================] - 0s 1ms/step - loss: 18.8651
# Epoch 201/500
# 34/34 [==============================] - 0s 1ms/step - loss: 18.8614
# Epoch 202/500
# 34/34 [==============================] - 0s 1ms/step - loss: 19.8254
# Epoch 203/500
# 34/34 [==============================] - 0s 1ms/step - loss: 19.1992
# Epoch 204/500
# 34/34 [==============================] - 0s 2ms/step - loss: 18.7592
# Epoch 205/500
# 34/34 [==============================] - 0s 1ms/step - loss: 18.5022
# Epoch 206/500
# 34/34 [==============================] - 0s 1ms/step - loss: 18.4258
# Epoch 207/500
# 34/34 [==============================] - 0s 1ms/step - loss: 18.9492
# Epoch 208/500
# 34/34 [==============================] - 0s 1ms/step - loss: 18.7940
# Epoch 209/500
# 34/34 [==============================] - 0s 1ms/step - loss: 18.3662
# Epoch 210/500
# 34/34 [==============================] - 0s 1ms/step - loss: 18.8040
# Epoch 211/500
# 34/34 [==============================] - 0s 1ms/step - loss: 18.5579
# Epoch 212/500
# 34/34 [==============================] - 0s 1ms/step - loss: 19.1992
# Epoch 213/500
# 34/34 [==============================] - 0s 1ms/step - loss: 18.4279
# Epoch 214/500
# 34/34 [==============================] - 0s 1ms/step - loss: 18.8352
# Epoch 215/500
# 34/34 [==============================] - 0s 1ms/step - loss: 19.3521
# Epoch 216/500
# 34/34 [==============================] - 0s 1ms/step - loss: 18.6229
# Epoch 217/500
# 34/34 [==============================] - 0s 1ms/step - loss: 18.7422
# Epoch 218/500
# 34/34 [==============================] - 0s 1ms/step - loss: 18.4874
# Epoch 219/500
# 34/34 [==============================] - 0s 1ms/step - loss: 18.1156
# Epoch 220/500
# 34/34 [==============================] - 0s 968us/step - loss: 18.2665
# Epoch 221/500
# 34/34 [==============================] - 0s 1ms/step - loss: 18.2128
# Epoch 222/500
# 34/34 [==============================] - 0s 1ms/step - loss: 18.8284
# Epoch 223/500
# 34/34 [==============================] - 0s 1ms/step - loss: 18.8862
# Epoch 224/500
# 34/34 [==============================] - 0s 1ms/step - loss: 18.0790
# Epoch 225/500
# 34/34 [==============================] - 0s 1ms/step - loss: 18.4884
# Epoch 226/500
# 34/34 [==============================] - 0s 1ms/step - loss: 19.0852
# Epoch 227/500
# 34/34 [==============================] - 0s 1ms/step - loss: 18.6630
# Epoch 228/500
# 34/34 [==============================] - 0s 1ms/step - loss: 18.1729
# Epoch 229/500
# 34/34 [==============================] - 0s 1ms/step - loss: 17.9008
# Epoch 230/500
# 34/34 [==============================] - 0s 2ms/step - loss: 18.7742
# Epoch 231/500
# 34/34 [==============================] - 0s 1ms/step - loss: 18.8789
# Epoch 232/500
# 34/34 [==============================] - 0s 2ms/step - loss: 18.3859
# Epoch 233/500
# 34/34 [==============================] - 0s 1ms/step - loss: 18.3308
# Epoch 234/500
# 34/34 [==============================] - 0s 1ms/step - loss: 18.1818
# Epoch 235/500
# 34/34 [==============================] - 0s 1ms/step - loss: 18.0359
# Epoch 236/500
# 34/34 [==============================] - 0s 1ms/step - loss: 17.9697
# Epoch 237/500
# 34/34 [==============================] - 0s 1ms/step - loss: 18.0584
# Epoch 238/500
# 34/34 [==============================] - 0s 1ms/step - loss: 17.9138
# Epoch 239/500
# 34/34 [==============================] - 0s 1ms/step - loss: 18.1003
# Epoch 240/500
# 34/34 [==============================] - 0s 1ms/step - loss: 18.3754
# Epoch 241/500
# 34/34 [==============================] - 0s 1ms/step - loss: 18.1693
# Epoch 242/500
# 34/34 [==============================] - 0s 1ms/step - loss: 18.0507
# Epoch 243/500
# 34/34 [==============================] - 0s 1ms/step - loss: 18.8291
# Epoch 244/500
# 34/34 [==============================] - 0s 1ms/step - loss: 19.0609
# Epoch 245/500
# 34/34 [==============================] - 0s 1ms/step - loss: 18.3908
# Epoch 246/500
# 34/34 [==============================] - 0s 1ms/step - loss: 17.8844
# Epoch 247/500
# 34/34 [==============================] - 0s 1ms/step - loss: 18.5896
# Epoch 248/500
# 34/34 [==============================] - 0s 1ms/step - loss: 18.0278
# Epoch 249/500
# 34/34 [==============================] - 0s 1ms/step - loss: 17.9520
# Epoch 250/500
# 34/34 [==============================] - 0s 1ms/step - loss: 18.0055
# Epoch 251/500
# 34/34 [==============================] - 0s 1ms/step - loss: 17.8244
# Epoch 252/500
# 34/34 [==============================] - 0s 1ms/step - loss: 17.9868
# Epoch 253/500
# 34/34 [==============================] - 0s 1ms/step - loss: 17.7269
# Epoch 254/500
# 34/34 [==============================] - 0s 1ms/step - loss: 17.6638
# Epoch 255/500
# 34/34 [==============================] - 0s 1ms/step - loss: 17.9256
# Epoch 256/500
# 34/34 [==============================] - 0s 1ms/step - loss: 17.7937
# Epoch 257/500
# 34/34 [==============================] - 0s 1ms/step - loss: 18.2626
# Epoch 258/500
# 34/34 [==============================] - 0s 1ms/step - loss: 17.6860
# Epoch 259/500
# 34/34 [==============================] - 0s 1ms/step - loss: 17.5915
# Epoch 260/500
# 34/34 [==============================] - 0s 1ms/step - loss: 17.5255
# Epoch 261/500
# 34/34 [==============================] - 0s 1ms/step - loss: 18.9592
# Epoch 262/500
# 34/34 [==============================] - 0s 1ms/step - loss: 18.3540
# Epoch 263/500
# 34/34 [==============================] - 0s 1ms/step - loss: 18.6158
# Epoch 264/500
# 34/34 [==============================] - 0s 1ms/step - loss: 18.1947
# Epoch 265/500
# 34/34 [==============================] - 0s 1ms/step - loss: 17.4949
# Epoch 266/500
# 34/34 [==============================] - 0s 1ms/step - loss: 17.7870
# Epoch 267/500
# 34/34 [==============================] - 0s 1ms/step - loss: 17.5897
# Epoch 268/500
# 34/34 [==============================] - 0s 1ms/step - loss: 17.8319
# Epoch 269/500
# 34/34 [==============================] - 0s 1ms/step - loss: 18.2391
# Epoch 270/500
# 34/34 [==============================] - 0s 1ms/step - loss: 17.4865
# Epoch 271/500
# 34/34 [==============================] - 0s 1ms/step - loss: 17.4531
# Epoch 272/500
# 34/34 [==============================] - 0s 1ms/step - loss: 17.3920
# Epoch 273/500
# 34/34 [==============================] - 0s 1ms/step - loss: 17.5662
# Epoch 274/500
# 34/34 [==============================] - 0s 1ms/step - loss: 17.2352
# Epoch 275/500
# 34/34 [==============================] - 0s 1ms/step - loss: 17.9466
# Epoch 276/500
# 34/34 [==============================] - 0s 1ms/step - loss: 17.6909
# Epoch 277/500
# 34/34 [==============================] - 0s 1ms/step - loss: 17.9285
# Epoch 278/500
# 34/34 [==============================] - 0s 1ms/step - loss: 18.0188
# Epoch 279/500
# 34/34 [==============================] - 0s 1ms/step - loss: 18.0958
# Epoch 280/500
# 34/34 [==============================] - 0s 1ms/step - loss: 17.4846
# Epoch 281/500
# 34/34 [==============================] - 0s 1ms/step - loss: 18.2235
# Epoch 282/500
# 34/34 [==============================] - 0s 1ms/step - loss: 18.2549
# Epoch 283/500
# 34/34 [==============================] - 0s 1ms/step - loss: 16.9657
# Epoch 284/500
# 34/34 [==============================] - 0s 1ms/step - loss: 17.0983
# Epoch 285/500
# 34/34 [==============================] - 0s 1ms/step - loss: 17.3322
# Epoch 286/500
# 34/34 [==============================] - 0s 1ms/step - loss: 18.2072
# Epoch 287/500
# 34/34 [==============================] - 0s 1ms/step - loss: 17.6621
# Epoch 288/500
# 34/34 [==============================] - 0s 1ms/step - loss: 17.2199
# Epoch 289/500
# 34/34 [==============================] - 0s 1ms/step - loss: 17.2638
# Epoch 290/500
# 34/34 [==============================] - 0s 1ms/step - loss: 17.3194
# Epoch 291/500
# 34/34 [==============================] - 0s 1ms/step - loss: 17.4943
# Epoch 292/500
# 34/34 [==============================] - 0s 1ms/step - loss: 17.1959
# Epoch 293/500
# 34/34 [==============================] - 0s 1ms/step - loss: 17.3360
# Epoch 294/500
# 34/34 [==============================] - 0s 2ms/step - loss: 17.9082
# Epoch 295/500
# 34/34 [==============================] - 0s 1ms/step - loss: 17.7564
# Epoch 296/500
# 34/34 [==============================] - 0s 1ms/step - loss: 17.3665
# Epoch 297/500
# 34/34 [==============================] - 0s 3ms/step - loss: 17.5196
# Epoch 298/500
# 34/34 [==============================] - 0s 1ms/step - loss: 18.3538
# Epoch 299/500
# 34/34 [==============================] - 0s 2ms/step - loss: 17.3491
# Epoch 300/500
# 34/34 [==============================] - 0s 1ms/step - loss: 17.4347
# Epoch 301/500
# 34/34 [==============================] - 0s 1ms/step - loss: 17.3109
# Epoch 302/500
# 34/34 [==============================] - 0s 1ms/step - loss: 17.5511
# Epoch 303/500
# 34/34 [==============================] - 0s 1ms/step - loss: 16.9779
# Epoch 304/500
# 34/34 [==============================] - 0s 966us/step - loss: 17.2209
# Epoch 305/500
# 34/34 [==============================] - 0s 1ms/step - loss: 17.1892
# Epoch 306/500
# 34/34 [==============================] - 0s 1ms/step - loss: 17.3756
# Epoch 307/500
# 34/34 [==============================] - 0s 1ms/step - loss: 17.2746
# Epoch 308/500
# 34/34 [==============================] - 0s 1ms/step - loss: 17.9435
# Epoch 309/500
# 34/34 [==============================] - 0s 1ms/step - loss: 16.6407
# Epoch 310/500
# 34/34 [==============================] - 0s 1ms/step - loss: 16.9298
# Epoch 311/500
# 34/34 [==============================] - 0s 1ms/step - loss: 16.9304
# Epoch 312/500
# 34/34 [==============================] - 0s 1ms/step - loss: 16.9146
# Epoch 313/500
# 34/34 [==============================] - 0s 1ms/step - loss: 17.8172
# Epoch 314/500
# 34/34 [==============================] - 0s 1ms/step - loss: 17.4527
# Epoch 315/500
# 34/34 [==============================] - 0s 1ms/step - loss: 16.6736
# Epoch 316/500
# 34/34 [==============================] - 0s 1ms/step - loss: 16.9343
# Epoch 317/500
# 34/34 [==============================] - 0s 1ms/step - loss: 17.1138
# Epoch 318/500
# 34/34 [==============================] - 0s 1ms/step - loss: 17.2561
# Epoch 319/500
# 34/34 [==============================] - 0s 1ms/step - loss: 16.9701
# Epoch 320/500
# 34/34 [==============================] - 0s 1ms/step - loss: 16.8494
# Epoch 321/500
# 34/34 [==============================] - 0s 1ms/step - loss: 16.9843
# Epoch 322/500
# 34/34 [==============================] - 0s 2ms/step - loss: 16.8155
# Epoch 323/500
# 34/34 [==============================] - 0s 1ms/step - loss: 16.8892
# Epoch 324/500
# 34/34 [==============================] - 0s 1ms/step - loss: 16.5923
# Epoch 325/500
# 34/34 [==============================] - 0s 1ms/step - loss: 16.5519
# Epoch 326/500
# 34/34 [==============================] - 0s 1ms/step - loss: 16.8005
# Epoch 327/500
# 34/34 [==============================] - 0s 1ms/step - loss: 16.7961
# Epoch 328/500
# 34/34 [==============================] - 0s 1ms/step - loss: 17.1567
# Epoch 329/500
# 34/34 [==============================] - 0s 1ms/step - loss: 17.2560
# Epoch 330/500
# 34/34 [==============================] - 0s 1ms/step - loss: 16.9845
# Epoch 331/500
# 34/34 [==============================] - 0s 1ms/step - loss: 16.7631
# Epoch 332/500
# 34/34 [==============================] - 0s 1ms/step - loss: 16.8024
# Epoch 333/500
# 34/34 [==============================] - 0s 1ms/step - loss: 16.7620
# Epoch 334/500
# 34/34 [==============================] - 0s 1ms/step - loss: 16.4440
# Epoch 335/500
# 34/34 [==============================] - 0s 1ms/step - loss: 17.2050
# Epoch 336/500
# 34/34 [==============================] - 0s 2ms/step - loss: 16.6407
# Epoch 337/500
# 34/34 [==============================] - 0s 1ms/step - loss: 16.4700
# Epoch 338/500
# 34/34 [==============================] - 0s 1ms/step - loss: 16.8735
# Epoch 339/500
# 34/34 [==============================] - 0s 3ms/step - loss: 16.6813
# Epoch 340/500
# 34/34 [==============================] - 0s 1ms/step - loss: 16.9910
# Epoch 341/500
# 34/34 [==============================] - 0s 1ms/step - loss: 16.8383
# Epoch 342/500
# 34/34 [==============================] - 0s 1ms/step - loss: 17.3150
# Epoch 343/500
# 34/34 [==============================] - 0s 1ms/step - loss: 16.7617
# Epoch 344/500
# 34/34 [==============================] - 0s 1ms/step - loss: 16.2913
# Epoch 345/500
# 34/34 [==============================] - 0s 1ms/step - loss: 16.6704
# Epoch 346/500
# 34/34 [==============================] - 0s 1ms/step - loss: 16.6301
# Epoch 347/500
# 34/34 [==============================] - 0s 1ms/step - loss: 16.6968
# Epoch 348/500
# 34/34 [==============================] - 0s 1ms/step - loss: 16.7220
# Epoch 349/500
# 34/34 [==============================] - 0s 1ms/step - loss: 16.6020
# Epoch 350/500
# 34/34 [==============================] - 0s 1ms/step - loss: 16.9855
# Epoch 351/500
# 34/34 [==============================] - 0s 1ms/step - loss: 16.5329
# Epoch 352/500
# 34/34 [==============================] - 0s 2ms/step - loss: 16.4619
# Epoch 353/500
# 34/34 [==============================] - 0s 1ms/step - loss: 16.9431
# Epoch 354/500
# 34/34 [==============================] - 0s 1ms/step - loss: 16.4111
# Epoch 355/500
# 34/34 [==============================] - 0s 1ms/step - loss: 16.4965
# Epoch 356/500
# 34/34 [==============================] - 0s 1ms/step - loss: 16.7440
# Epoch 357/500
# 34/34 [==============================] - 0s 1ms/step - loss: 16.8967
# Epoch 358/500
# 34/34 [==============================] - 0s 1ms/step - loss: 16.4493
# Epoch 359/500
# 34/34 [==============================] - 0s 1ms/step - loss: 16.0878
# Epoch 360/500
# 34/34 [==============================] - 0s 1ms/step - loss: 16.4420
# Epoch 361/500
# 34/34 [==============================] - 0s 1ms/step - loss: 16.4288
# Epoch 362/500
# 34/34 [==============================] - 0s 1ms/step - loss: 16.6275
# Epoch 363/500
# 34/34 [==============================] - 0s 1ms/step - loss: 16.5878
# Epoch 364/500
# 34/34 [==============================] - 0s 1ms/step - loss: 16.4425
# Epoch 365/500
# 34/34 [==============================] - 0s 1ms/step - loss: 16.0411
# Epoch 366/500
# 34/34 [==============================] - 0s 1ms/step - loss: 16.2750
# Epoch 367/500
# 34/34 [==============================] - 0s 1ms/step - loss: 16.3785
# Epoch 368/500
# 34/34 [==============================] - 0s 2ms/step - loss: 16.2337
# Epoch 369/500
# 34/34 [==============================] - 0s 1ms/step - loss: 16.4813
# Epoch 370/500
# 34/34 [==============================] - 0s 1ms/step - loss: 16.7311
# Epoch 371/500
# 34/34 [==============================] - 0s 1ms/step - loss: 17.0226
# Epoch 372/500
# 34/34 [==============================] - 0s 1ms/step - loss: 16.2362
# Epoch 373/500
# 34/34 [==============================] - 0s 1ms/step - loss: 16.4118
# Epoch 374/500
# 34/34 [==============================] - 0s 1ms/step - loss: 16.3216
# Epoch 375/500
# 34/34 [==============================] - 0s 1ms/step - loss: 16.0722
# Epoch 376/500
# 34/34 [==============================] - 0s 1ms/step - loss: 16.3489
# Epoch 377/500
# 34/34 [==============================] - 0s 1ms/step - loss: 16.6511
# Epoch 378/500
# 34/34 [==============================] - 0s 1ms/step - loss: 15.9635
# Epoch 379/500
# 34/34 [==============================] - 0s 2ms/step - loss: 16.3754
# Epoch 380/500
# 34/34 [==============================] - 0s 1ms/step - loss: 16.6189
# Epoch 381/500
# 34/34 [==============================] - 0s 2ms/step - loss: 16.1893
# Epoch 382/500
# 34/34 [==============================] - 0s 1ms/step - loss: 16.8609
# Epoch 383/500
# 34/34 [==============================] - 0s 1ms/step - loss: 16.2370
# Epoch 384/500
# 34/34 [==============================] - 0s 1ms/step - loss: 16.1308
# Epoch 385/500
# 34/34 [==============================] - 0s 1ms/step - loss: 16.0163
# Epoch 386/500
# 34/34 [==============================] - 0s 1ms/step - loss: 16.6533
# Epoch 387/500
# 34/34 [==============================] - 0s 1ms/step - loss: 16.4753
# Epoch 388/500
# 34/34 [==============================] - 0s 1ms/step - loss: 16.5508
# Epoch 389/500
# 34/34 [==============================] - 0s 970us/step - loss: 16.1513
# Epoch 390/500
# 34/34 [==============================] - 0s 1ms/step - loss: 16.3246
# Epoch 391/500
# 34/34 [==============================] - 0s 1ms/step - loss: 16.5956
# Epoch 392/500
# 34/34 [==============================] - 0s 1ms/step - loss: 16.1270
# Epoch 393/500
# 34/34 [==============================] - 0s 1ms/step - loss: 15.9922
# Epoch 394/500
# 34/34 [==============================] - 0s 1ms/step - loss: 16.4802
# Epoch 395/500
# 34/34 [==============================] - 0s 1ms/step - loss: 16.2083
# Epoch 396/500
# 34/34 [==============================] - 0s 1ms/step - loss: 16.6738
# Epoch 397/500
# 34/34 [==============================] - 0s 1ms/step - loss: 16.7968
# Epoch 398/500
# 34/34 [==============================] - 0s 1ms/step - loss: 16.6187
# Epoch 399/500
# 34/34 [==============================] - 0s 1ms/step - loss: 15.9229
# Epoch 400/500
# 34/34 [==============================] - 0s 1ms/step - loss: 16.7269
# Epoch 401/500
# 34/34 [==============================] - 0s 1ms/step - loss: 16.3559
# Epoch 402/500
# 34/34 [==============================] - 0s 1ms/step - loss: 16.4809
# Epoch 403/500
# 34/34 [==============================] - 0s 1ms/step - loss: 16.3218
# Epoch 404/500
# 34/34 [==============================] - 0s 1ms/step - loss: 16.7063
# Epoch 405/500
# 34/34 [==============================] - 0s 1ms/step - loss: 15.7354
# Epoch 406/500
# 34/34 [==============================] - 0s 1ms/step - loss: 15.8761
# Epoch 407/500
# 34/34 [==============================] - 0s 1ms/step - loss: 16.1058
# Epoch 408/500
# 34/34 [==============================] - 0s 1ms/step - loss: 16.0013
# Epoch 409/500
# 34/34 [==============================] - 0s 1ms/step - loss: 16.1973
# Epoch 410/500
# 34/34 [==============================] - 0s 1ms/step - loss: 15.9632
# Epoch 411/500
# 34/34 [==============================] - 0s 1ms/step - loss: 15.9900
# Epoch 412/500
# 34/34 [==============================] - 0s 1ms/step - loss: 16.1522
# Epoch 413/500
# 34/34 [==============================] - 0s 1ms/step - loss: 16.0852
# Epoch 414/500
# 34/34 [==============================] - 0s 1ms/step - loss: 15.9991
# Epoch 415/500
# 34/34 [==============================] - 0s 1ms/step - loss: 16.2396
# Epoch 416/500
# 34/34 [==============================] - 0s 1ms/step - loss: 16.0094
# Epoch 417/500
# 34/34 [==============================] - 0s 1ms/step - loss: 16.1597
# Epoch 418/500
# 34/34 [==============================] - 0s 1ms/step - loss: 15.9467
# Epoch 419/500
# 34/34 [==============================] - 0s 1ms/step - loss: 15.8177
# Epoch 420/500
# 34/34 [==============================] - 0s 1ms/step - loss: 16.0247
# Epoch 421/500
# 34/34 [==============================] - 0s 1ms/step - loss: 15.8373
# Epoch 422/500
# 34/34 [==============================] - 0s 1ms/step - loss: 16.5625
# Epoch 423/500
# 34/34 [==============================] - 0s 1ms/step - loss: 15.9317
# Epoch 424/500
# 34/34 [==============================] - 0s 1ms/step - loss: 15.6060
# Epoch 425/500
# 34/34 [==============================] - 0s 991us/step - loss: 15.7870
# Epoch 426/500
# 34/34 [==============================] - 0s 1ms/step - loss: 15.9109
# Epoch 427/500
# 34/34 [==============================] - 0s 1ms/step - loss: 15.8725
# Epoch 428/500
# 34/34 [==============================] - 0s 1ms/step - loss: 15.7655
# Epoch 429/500
# 34/34 [==============================] - 0s 1ms/step - loss: 16.1306
# Epoch 430/500
# 34/34 [==============================] - 0s 1ms/step - loss: 15.8613
# Epoch 431/500
# 34/34 [==============================] - 0s 1ms/step - loss: 16.3048
# Epoch 432/500
# 34/34 [==============================] - 0s 1ms/step - loss: 15.7437
# Epoch 433/500
# 34/34 [==============================] - 0s 1ms/step - loss: 15.9304
# Epoch 434/500
# 34/34 [==============================] - 0s 1ms/step - loss: 16.0951
# Epoch 435/500
# 34/34 [==============================] - 0s 1ms/step - loss: 15.7205
# Epoch 436/500
# 34/34 [==============================] - 0s 1ms/step - loss: 15.9898
# Epoch 437/500
# 34/34 [==============================] - 0s 1ms/step - loss: 15.9821
# Epoch 438/500
# 34/34 [==============================] - 0s 1ms/step - loss: 16.1596
# Epoch 439/500
# 34/34 [==============================] - 0s 1ms/step - loss: 15.8427
# Epoch 440/500
# 34/34 [==============================] - 0s 1ms/step - loss: 15.7032
# Epoch 441/500
# 34/34 [==============================] - 0s 1ms/step - loss: 15.7521
# Epoch 442/500
# 34/34 [==============================] - 0s 1ms/step - loss: 15.5793
# Epoch 443/500
# 34/34 [==============================] - 0s 1ms/step - loss: 16.1283
# Epoch 444/500
# 34/34 [==============================] - 0s 1ms/step - loss: 15.8840
# Epoch 445/500
# 34/34 [==============================] - 0s 1ms/step - loss: 15.7608
# Epoch 446/500
# 34/34 [==============================] - 0s 1ms/step - loss: 15.6404
# Epoch 447/500
# 34/34 [==============================] - 0s 1ms/step - loss: 15.9587
# Epoch 448/500
# 34/34 [==============================] - 0s 1ms/step - loss: 15.7399
# Epoch 449/500
# 34/34 [==============================] - 0s 1ms/step - loss: 15.8200
# Epoch 450/500
# 34/34 [==============================] - 0s 1ms/step - loss: 16.2617
# Epoch 451/500
# 34/34 [==============================] - 0s 1ms/step - loss: 15.9670
# Epoch 452/500
# 34/34 [==============================] - 0s 1ms/step - loss: 16.0588
# Epoch 453/500
# 34/34 [==============================] - 0s 1ms/step - loss: 16.1518
# Epoch 454/500
# 34/34 [==============================] - 0s 1ms/step - loss: 16.0040
# Epoch 455/500
# 34/34 [==============================] - 0s 1ms/step - loss: 15.5050
# Epoch 456/500
# 34/34 [==============================] - 0s 1ms/step - loss: 15.9740
# Epoch 457/500
# 34/34 [==============================] - 0s 1ms/step - loss: 15.8319
# Epoch 458/500
# 34/34 [==============================] - 0s 1ms/step - loss: 15.6423
# Epoch 459/500
# 34/34 [==============================] - 0s 1ms/step - loss: 15.3937
# Epoch 460/500
# 34/34 [==============================] - 0s 1ms/step - loss: 15.8706
# Epoch 461/500
# 34/34 [==============================] - 0s 1ms/step - loss: 15.5037
# Epoch 462/500
# 34/34 [==============================] - 0s 1ms/step - loss: 15.6199
# Epoch 463/500
# 34/34 [==============================] - 0s 1ms/step - loss: 15.4949
# Epoch 464/500
# 34/34 [==============================] - 0s 1ms/step - loss: 15.6620
# Epoch 465/500
# 34/34 [==============================] - 0s 1ms/step - loss: 15.9531
# Epoch 466/500
# 34/34 [==============================] - 0s 1ms/step - loss: 15.6101
# Epoch 467/500
# 34/34 [==============================] - 0s 2ms/step - loss: 15.3642
# Epoch 468/500
# 34/34 [==============================] - 0s 1ms/step - loss: 15.5916
# Epoch 469/500
# 34/34 [==============================] - 0s 1ms/step - loss: 15.6915
# Epoch 470/500
# 34/34 [==============================] - 0s 1ms/step - loss: 15.7840
# Epoch 471/500
# 34/34 [==============================] - 0s 1ms/step - loss: 15.6257
# Epoch 472/500
# 34/34 [==============================] - 0s 1ms/step - loss: 16.1081
# Epoch 473/500
# 34/34 [==============================] - 0s 1ms/step - loss: 16.3505
# Epoch 474/500
# 34/34 [==============================] - 0s 1ms/step - loss: 15.5315
# Epoch 475/500
# 34/34 [==============================] - 0s 1ms/step - loss: 16.6230
# Epoch 476/500
# 34/34 [==============================] - 0s 1ms/step - loss: 16.1057
# Epoch 477/500
# 34/34 [==============================] - 0s 1ms/step - loss: 15.4468
# Epoch 478/500
# 34/34 [==============================] - 0s 1ms/step - loss: 15.4014
# Epoch 479/500
# 34/34 [==============================] - 0s 1ms/step - loss: 15.4714
# Epoch 480/500
# 34/34 [==============================] - 0s 1ms/step - loss: 15.6583
# Epoch 481/500
# 34/34 [==============================] - 0s 1ms/step - loss: 17.8709
# Epoch 482/500
# 34/34 [==============================] - 0s 1ms/step - loss: 16.2748
# Epoch 483/500
# 34/34 [==============================] - 0s 1ms/step - loss: 15.5587
# Epoch 484/500
# 34/34 [==============================] - 0s 1ms/step - loss: 15.4202
# Epoch 485/500
# 34/34 [==============================] - 0s 1ms/step - loss: 15.8252
# Epoch 486/500
# 34/34 [==============================] - 0s 1ms/step - loss: 15.6531
# Epoch 487/500
# 34/34 [==============================] - 0s 1ms/step - loss: 15.5383
# Epoch 488/500
# 34/34 [==============================] - 0s 2ms/step - loss: 15.3012
# Epoch 489/500
# 34/34 [==============================] - 0s 1ms/step - loss: 15.4501
# Epoch 490/500
# 34/34 [==============================] - 0s 2ms/step - loss: 15.5391
# Epoch 491/500
# 34/34 [==============================] - 0s 1ms/step - loss: 15.4958
# Epoch 492/500
# 34/34 [==============================] - 0s 1ms/step - loss: 15.5539
# Epoch 493/500
# 34/34 [==============================] - 0s 1ms/step - loss: 15.4057
# Epoch 494/500
# 34/34 [==============================] - 0s 943us/step - loss: 15.5273
# Epoch 495/500
# 34/34 [==============================] - 0s 2ms/step - loss: 15.9146
# Epoch 496/500
# 34/34 [==============================] - 0s 1ms/step - loss: 15.5342
# Epoch 497/500
# 34/34 [==============================] - 0s 2ms/step - loss: 15.3673
# Epoch 498/500
# 34/34 [==============================] - 0s 1ms/step - loss: 15.4015
# Epoch 499/500
# 34/34 [==============================] - 0s 1ms/step - loss: 15.6451
# Epoch 500/500
# 34/34 [==============================] - 0s 1ms/step - loss: 15.4464

# %% [markdown]
# ## Evaluating the forecast
#
# Now it is time to evaluate the performance of the forecast. For this you can use the `compute_metrics` function that you coded in the previous assignment:

# %%
def compute_metrics(true_series, forecast):
    
    mse = tf.keras.metrics.mean_squared_error(true_series, forecast).numpy()
    mae = tf.keras.metrics.mean_absolute_error(true_series, forecast).numpy()

    return mse, mae

# %% [markdown]
# At this point only the model that will perform the forecast is ready but you still need to compute the actual forecast.
#
# For this, run the cell below which uses the `generate_forecast` function to compute the forecast. This function generates the next value given a set of the previous `window_size` points for every point in the validation set.

# %%
def generate_forecast(series=G.SERIES, split_time=G.SPLIT_TIME, window_size=G.WINDOW_SIZE):
    forecast = []
    for time in range(len(series) - window_size):
        forecast.append(model.predict(series[time:time + window_size][np.newaxis]))

    forecast = forecast[split_time-window_size:]
    results = np.array(forecast)[:, 0, 0]
    return results


# Save the forecast
dnn_forecast = generate_forecast()

# Plot it
plt.figure(figsize=(10, 6))
plot_series(time_valid, series_valid)
plot_series(time_valid, dnn_forecast)

# %% [markdown]
# **Expected Output:**
#
# A series similar to this one:
#
# <div>
# <img src="images/forecast.png" width="500"/>
# </div>

# %%
mse, mae = compute_metrics(series_valid, dnn_forecast)

print(f"mse: {mse:.2f}, mae: {mae:.2f} for forecast")
# Out:
# mse: 23.38, mae: 3.10 for forecast

# %% [markdown]
# **To pass this assignment your forecast should achieve an MSE of 30 or less.**
#
# - If your forecast didn't achieve this threshold try re-training your model with a different architecture or tweaking the optimizer's parameters.
#
#
# - If your forecast did achieve this threshold run the following cell to save your model in a HDF5 file file which will be used for grading and after doing so, submit your assigment for grading.
#
#
# - Make sure you didn't use `Lambda` layers in your model since these are incompatible with the `HDF5` format which will be used to save your model for grading.
#
#
# - This environment includes a dummy `my_model.h5` file which is just a dummy model trained for one epoch. **To replace this file with your actual model you need to run the next cell before submitting for grading.**

# %%
# Save your model in HDF5 format
model.save('my_model.h5')

# %% [markdown]
# **Congratulations on finishing this week's assignment!**
#
# You have successfully implemented a neural network capable of forecasting time series while also learning how to leverage Tensorflow's Dataset class to process time series data!
#
# **Keep it up!**

# %% [markdown]
# <details>
#   <summary><font size="2" color="darkgreen"><b>Please click here if you want to experiment with any of the non-graded code.</b></font></summary>
#     <p><i><b>Important Note: Please only do this when you've already passed the assignment to avoid problems with the autograder.</b></i>
#     <ol>
#         <li> On the notebook’s menu, click “View” > “Cell Toolbar” > “Edit Metadata”</li>
#         <li> Hit the “Edit Metadata” button next to the code cell which you want to lock/unlock</li>
#         <li> Set the attribute value for “editable” to:
#             <ul>
#                 <li> “true” if you want to unlock it </li>
#                 <li> “false” if you want to lock it </li>
#             </ul>
#         </li>
#         <li> On the notebook’s menu, click “View” > “Cell Toolbar” > “None” </li>
#     </ol>
#     <p> Here's a short demo of how to do the steps above:
#         <br>
#         <img src="https://drive.google.com/uc?export=view&id=14Xy_Mb17CZVgzVAgq7NCjMVBvSae3xO1" align="center">
# </details>
